# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import os
import pathlib
from pathlib import Path
from typing import Tuple, Dict, List
# 查找指定文件夹中的classes

# 设置数据文件夹
DATA_PATH = Path("data/")
IMAGE_PATH = DATA_PATH / "wordlib"    #
IMAGE_PATH_LIST = list(IMAGE_PATH.glob("*.gif"))  

# 如果文件夹不存在，则创建一个... 
if IMAGE_PATH.is_dir():
    print(f"{IMAGE_PATH} 文件夹存在，可以使用...")
else:
    print(f"{IMAGE_PATH}文件平不存在，创建中...")
    IMAGE_PATH.mkdir(parents=True, exist_ok=True)

# ### 准备数据，查找指定文件夹中包含哪些文字，并设置其classes和labels

def find_classes(directory: str,ext:str='gif',scan_images=True) -> Tuple[List[str], Dict[str, int],List[str]]:
    """根据指定文件夹下的图片文件名的第一名字形成类别classes.
    
    书法图片文件命名规范为：字_字体_书法家_文件编号.gif，如：予_行书_鲜于枢_12046.gif.

    Args:
        directory (str): target directory to load distinct words from.

    Returns:
        Tuple[List[str], Dict[str, int]]: (list_of_class_names, dict(class_name: idx...))
    
    Example:
        data\wordlib\予_行书_鲜于枢_12046.gif 分割_前面的字符是书法对应的文字
        >>> (["予", "大",...], {"予": 203, ...})
    """
    image_classes_set = set()  #因为相同的字有多张图，所以使用set集合去重
    images_classes_list=[]
    images_name_list=[]
    # 创建汉字列表及包含其序号的dict
    class_to_idx=dict()

    if scan_images:

        # 1. 扫描路径下全部文件，通过文件名首字符为图片所对应的汉字这样的命名规则，得到该路径下的全部汉字。
        image_path_list = list(pathlib.Path(directory).glob(f"*.{ext}"))

        for  path in   image_path_list:
            image_classes_set.add(path.name.split('_')[0])
            images_name_list.append(path.name)
        classes=sorted([word for word in image_classes_set])
        
        # 2. 如果文件不存在或没有按要求命名，则报错
        if not classes:
            raise FileNotFoundError(f"{directory}路径下的文件可能不存在或没有按要求命名（文件命名规则为word_font_writer_number.gif)")
   
        for i,word in enumerate(classes):
            class_to_idx[word]=i   
        
        # 3. 将图片文件扫描及解析的结果保存到csv文件
        df_classes=pd.DataFrame(classes,columns=['classes'])
        df_class_to_idx=pd.DataFrame(list(class_to_idx.items()),columns=['classes','idx'])
        df_class_to_idx=df_class_to_idx.set_index('classes')
        df_images_name_list=pd.DataFrame(images_name_list,columns=['images'])
        df_classes.to_csv('data/bd_classes.csv',header=True,index=False)
        df_class_to_idx.to_csv('data/bd_class_to_idx.csv',header=True)
        df_images_name_list.to_csv('data/bd_images_names.csv',header=True,index=False)
    else:
        df_classes=pd.read_csv('data/bd_classes.csv',header=0)
        classes=list(df_classes['classes'])

        df_class_to_idx=pd.read_csv('data/bd_class_to_idx.csv',header=0)
        class_to_idx=dict(zip(df_class_to_idx['classes'],df_class_to_idx['idx']))

        df_images_name_list=pd.read_csv('data/bd_images_names.csv',header=0)
        images_name_list=list(df_images_name_list['images'])

    return classes, class_to_idx, images_name_list


##  是模型训练的基础数据，重要，不要改动
images_classes_list,word_classes_dict,images_name_list=find_classes(IMAGE_PATH,'gif')
# Out:
# data\wordlib 文件夹存在，可以使用...

# %%
images_classes_list,word_classes_dict,images_name_list=find_classes(IMAGE_PATH,'gif',scan_images=False)

# %%
def find_writer_classes(directory: str,ext:str='gif',scan_images=True) -> Tuple[List[str], Dict[str, int],List[str]]:
    """根据指定文件夹下的图片文件名的第一名字形成类别classes.
    
    书法图片文件命名规范为：字_字体_书法家_文件编号.gif，如：予_行书_鲜于枢_12046.gif.

    Args:
        directory (str): target directory to load distinct words from.

    Returns:
        Tuple[List[str], Dict[str, int]]: (list_of_class_names, dict(class_name: idx...))
    
    Example:
        data\wordlib\予_行书_鲜于枢_12046.gif 最后一个分割符_后面的字符是书法对应的作者writer
        >>> (["鲜于枢", "王羲之"], {"王羲之": 266, ...})
    """
    # 1. 扫描路径下全部文件，通过文件名首字符为图片所对应的汉字这样的命名规则，得到该路径下的全部汉字。
    
    image_writer_classes_set = set()  #因为相同的字有多张图，所以使用set集合去重
    images_writer_classes_list=[]
    images_writer_name_list=[]
    writer_class_to_idx=dict()

    if scan_images:
        # 1. 扫描路径下全部文件，通过文件名首字符为图片所对应的汉字这样的命名规则，得到该路径下的全部汉字。
        image_path_list = list(pathlib.Path(directory).glob(f"*.{ext}"))
        
        for  path in   image_path_list:
            image_writer_classes_set.add(path.name.split('_')[2])
            images_writer_name_list.append(path.name)

        writer_classes=sorted([word for word in image_writer_classes_set])

        # 2. 如果文件不存在或没有按要求命名，则报错
        if not writer_classes:
            raise FileNotFoundError(f"{directory}路径下的文件可能不存在或没有按要求命名（文件命名规则为word_font_writer_number.gif)")

        # 3. 创建汉字列表及包含其序号的dict

        for i,word in enumerate(writer_classes):
            writer_class_to_idx[word]=i   
        
        # 3. 将图片文件扫描及解析的结果保存到csv文件
        df_writer_classes=pd.DataFrame(writer_classes,columns=['writer_classes'])
        df_writer_class_to_idx=pd.DataFrame(list(writer_class_to_idx.items()),columns=['writer_classes','idx'])
        df_writer_class_to_idx=df_writer_class_to_idx.set_index('writer_classes')
        df_images_writer_name_list=pd.DataFrame(images_writer_name_list,columns=['images'])
        df_writer_classes.to_csv('data/bd_writer_classes.csv',header=True,index=False)
        df_writer_class_to_idx.to_csv('data/bd_writer_class_to_idx.csv',header=True)
        df_images_writer_name_list.to_csv('data/bd_images_writer_name.csv',header=True,index=False)
    else:
        df_writer_classes=pd.read_csv('data/bd_writer_classes.csv',header=0)
        writer_classes=list(df_writer_classes['writer_classes'])

        df_writer_class_to_idx=pd.read_csv('data/bd_writer_class_to_idx.csv',header=0)
        writer_class_to_idx=dict(zip(df_writer_class_to_idx['writer_classes'],df_writer_class_to_idx['idx']))

        df_images_writer_name_list=pd.read_csv('data/bd_images_writer_name.csv',header=0)
        images_writer_name_list=list(df_images_writer_name_list['images'])

    


    return writer_classes, writer_class_to_idx, images_writer_name_list

##  是模型训练的基础数据，重要，不要改动
images_writer_classes_list,word_writer_classes_dict,images_writer_name_list=find_writer_classes(IMAGE_PATH,'gif')

# %%
images_writer_classes_list,word_writer_classes_dict,images_writer_name_list=find_writer_classes(IMAGE_PATH,'gif',scan_images=False)

# %%
images_writer_name_list
# Out:
# ['一_楷书_孙秋生造像_103084.gif',
#  '一_楷书_柳公权_103080.gif',
#  '一_楷书_柳公权_103081.gif',
#  '一_楷书_欧阳询_103082.gif',
#  '一_楷书_欧阳询_103083.gif',
#  '一_楷书_虞世南_103087.gif',
#  '一_楷书_褚遂良_103077.gif',
#  '一_楷书_褚遂良_103078.gif',
#  '一_楷书_颜真卿_103085.gif',
#  '一_楷书_颜真卿_103086.gif',
#  '一_楷书_高贞碑_103079.gif',
#  '一_篆书_徐三庚_1.gif',
#  '一_草书_吴镇_131000.gif',
#  '一_草书_孙过庭_130992.gif',
#  '一_草书_宋克_130991.gif',
#  '一_草书_张旭_131013.gif',
#  '一_草书_张瑞图_131012.gif',
#  '一_草书_张芝_131014.gif',
#  '一_草书_徐伯清_131002.gif',
#  '一_草书_徐伯清_131003.gif',
#  '一_草书_徐伯清_131004.gif',
#  '一_草书_徐伯清_131005.gif',
#  '一_草书_徐伯清_131006.gif',
#  '一_草书_徐伯清_131007.gif',
#  '一_草书_徐伯清_131008.gif',
#  '一_草书_徐伯清_131009.gif',
#  '一_草书_徐伯清_131010.gif',
#  '一_草书_徐伯清_131011.gif',
#  '一_草书_怀素_130982.gif',
#  '一_草书_怀素_130983.gif',
#  '一_草书_敬世江_130987.gif',
#  '一_草书_文天祥_130999.gif',
#  '一_草书_杜预_130981.gif',
#  '一_草书_毛泽东_130989.gif',
#  '一_草书_王守仁_130993.gif',
#  '一_草书_王羲之_130994.gif',
#  '一_草书_王羲之_130995.gif',
#  '一_草书_王羲之_130996.gif',
#  '一_草书_王羲之_130997.gif',
#  '一_草书_王羲之_130998.gif',
#  '一_草书_皇象_130984.gif',
#  '一_草书_米芾_130990.gif',
#  '一_草书_萧衍_131001.gif',
#  '一_草书_赵子昂_131015.gif',
#  '一_草书_陆游_130988.gif',
#  '一_草书_黄庭坚_130985.gif',
#  '一_草书_黄庭坚_130986.gif',
#  '一_行书_孙虔礼_10928.gif',
#  '一_行书_敬世江_10922.gif',
#  '一_行书_李怀琳_10923.gif',
#  '一_行书_杜预_10918.gif',
#  '一_行书_查士标_10916.gif',
#  '一_行书_王庭筠_10929.gif',
#  '一_行书_王羲之_10930.gif',
#  '一_行书_王羲之_10931.gif',
#  '一_行书_王羲之_10932.gif',
#  '一_行书_王羲之_10933.gif',
#  '一_行书_皇象_10919.gif',
#  '一_行书_米芾_10925.gif',
#  '一_行书_米芾_10926.gif',
#  '一_行书_苏轼_10927.gif',
#  '一_行书_萧衍_10935.gif',
#  '一_行书_董其昌_10917.gif',
#  '一_行书_解缙_10921.gif',
#  '一_行书_陆柬之_10924.gif',
#  '一_行书_鲜于枢_10934.gif',
#  '一_行书_黄庭坚_10920.gif',
#  '一_隶书_唐玄宗_78367.gif',
#  '一_隶书_朝侯残碑_78363.gif',
#  '一_隶书_赵之谦_78368.gif',
#  '一_隶书_顾蔼吉_78364.gif',
#  '一_隶书_马王堆帛书_78365.gif',
#  '一_隶书_马王堆帛书_78366.gif',
#  '丁_楷书_崔敬邕墓志_103089.gif',
#  '丁_楷书_张猛龙碑_103092.gif',
#  '丁_楷书_智永_103094.gif',
#  '丁_楷书_欧阳通_103090.gif',
#  '丁_楷书_褚遂良_103088.gif',
#  '丁_楷书_赵孟頫_103093.gif',
#  '丁_楷书_颜真卿_103091.gif',
#  '丁_篆书_胡义赞_2.gif',
#  '丁_篆书_说文解字_3.gif',
#  '丁_草书_孙过庭_131027.gif',
#  '丁_草书_孙过庭_131028.gif',
#  '丁_草书_宋克_131026.gif',
#  '丁_草书_徐伯清_131030.gif',
#  '丁_草书_徐伯清_131031.gif',
#  '丁_草书_怀素_131017.gif',
#  '丁_草书_怀素_131018.gif',
#  '丁_草书_怀素_131019.gif',
#  '丁_草书_怀素_131020.gif',
#  '丁_草书_揭傒斯_131021.gif',
#  '丁_草书_敬世江_131022.gif',
#  '丁_草书_智永_131036.gif',
#  '丁_草书_欧阳询_131025.gif',
#  '丁_草书_毛泽东_131024.gif',
#  '丁_草书_王铎_131029.gif',
#  '丁_草书_程京萼_131016.gif',
#  '丁_草书_赵佶_131033.gif',
#  '丁_草书_赵子昂_131035.gif',
#  '丁_草书_赵构_131032.gif',
#  '丁_草书_赵雍_131034.gif',
#  '丁_草书_陆游_131023.gif',
#  '丁_行书_孙过庭_10942.gif',
#  '丁_行书_敬世江_10937.gif',
#  '丁_行书_智永_10943.gif',
#  '丁_行书_智永_10944.gif',
#  '丁_行书_欧阳询_10940.gif',
#  '丁_行书_沈粲_10941.gif',
#  '丁_行书_米芾_10938.gif',
#  '丁_行书_米芾_10939.gif',
#  '丁_行书_黄庭坚_10936.gif',
#  '丁_隶书_居延简_78371.gif',
#  '丁_隶书_赵宽碑_78372.gif',
#  '丁_隶书_邓石如_78370.gif',
#  '丁_隶书_陈鸿寿_78369.gif',
#  '七_楷书_孙秋生造像_103102.gif',
#  '七_楷书_安乐王墓志_103095.gif',
#  '七_楷书_敬使君碑_103099.gif',
#  '七_楷书_柳公权_103100.gif',
#  '七_楷书_欧阳通_103101.gif',
#  '七_楷书_虞世南_103105.gif',
#  '七_楷书_褚遂良_103096.gif',
#  '七_楷书_褚遂良_103097.gif',
#  '七_楷书_褚遂良_103098.gif',
#  '七_楷书_颜真卿_103103.gif',
#  '七_楷书_颜真卿_103104.gif',
#  '七_篆书_会稽刻石_5.gif',
#  '七_篆书_邓石如_4.gif',
#  '七_草书_徐伯清_131048.gif',
#  '七_草书_徐伯清_131049.gif',
#  '七_草书_敬世江_131037.gif',
#  '七_草书_文征明_131047.gif',
#  '七_草书_智永_131050.gif',
#  '七_草书_柳公权_131038.gif',
#  '七_草书_毛泽东_131041.gif',
#  '七_草书_王献之_131046.gif',
#  '七_草书_王羲之_131042.gif',
#  '七_草书_王羲之_131043.gif',
#  '七_草书_王羲之_131044.gif',
#  '七_草书_王羲之_131045.gif',
#  '七_草书_陆游_131039.gif',
#  '七_草书_马愈_131040.gif',
#  '七_行书_孙过庭_10948.gif',
#  '七_行书_敬世江_10946.gif',
#  '七_行书_王慈_10950.gif',
#  '七_行书_王羲之_10951.gif',
#  '七_行书_王羲之_10952.gif',
#  '七_行书_王羲之_10953.gif',
#  '七_行书_王羲之_10954.gif',
#  '七_行书_米芾_10947.gif',
#  '七_行书_索靖_10949.gif',
#  '七_行书_董其昌_10945.gif',
#  '七_行书_赵孟頫_10955.gif',
#  '七_隶书_史晨碑_78377.gif',
#  '七_隶书_唐玄宗_78379.gif',
#  '七_隶书_张迁碑_78381.gif',
#  '七_隶书_曹全碑_78373.gif',
#  '七_隶书_杨沂孙_78380.gif',
#  '七_隶书_泰山金刚经_78378.gif',
#  '七_隶书_衡方碑_78375.gif',
#  '七_隶书_陈鸿寿_78374.gif',
#  '七_隶书_马王堆帛书_78376.gif',
#  '万_楷书_始平公造像_103110.gif',
#  '万_楷书_孙秋生造像_103111.gif',
#  '万_楷书_孙秋生造像_103112.gif',
#  '万_楷书_张猛龙碑_103116.gif',
#  '万_楷书_欧阳询_103108.gif',
#  '万_楷书_欧阳询_103109.gif',
#  '万_楷书_虞世南_103115.gif',
#  '万_楷书_褚遂良_103106.gif',
#  '万_楷书_赵之谦_103119.gif',
#  '万_楷书_赵佶_103117.gif',
#  '万_楷书_赵孟頫_103118.gif',
#  '万_楷书_颜真卿_103113.gif',
#  '万_楷书_颜真卿_103114.gif',
#  '万_楷书_龙藏寺碑_103107.gif',
#  '万_篆书_会稽刻石_8.gif',
#  '万_篆书_吴大澄_11.gif',
#  '万_篆书_吴昌硕_10.gif',
#  '万_篆书_王澍_9.gif',
#  '万_篆书_胡澍_7.gif',
#  '万_篆书_邓石如_6.gif',
#  '万_草书_何绍基_131054.gif',
#  '万_草书_出师颂_131052.gif',
#  '万_草书_孙过庭_131067.gif',
#  '万_草书_宋克_131066.gif',
#  '万_草书_张旭_131082.gif',
#  '万_草书_张瑞图_131081.gif',
#  '万_草书_徐伯清_131076.gif',
#  '万_草书_徐伯清_131077.gif',
#  '万_草书_徐伯清_131078.gif',
#  '万_草书_怀素_131055.gif',
#  '万_草书_怀素_131056.gif',
#  '万_草书_怀素_131057.gif',
#  '万_草书_怀素_131058.gif',
#  '万_草书_敬世江_131063.gif',
#  '万_草书_文征明_131074.gif',
#  '万_草书_智永_131087.gif',
#  '万_草书_智永_131088.gif',
#  '万_草书_智永_131089.gif',
#  '万_草书_杨万里_131079.gif',
#  '万_草书_毛泽东_131064.gif',
#  '万_草书_法若真_131053.gif',
#  '万_草书_王宠_131069.gif',
#  '万_草书_王羲之_131071.gif',
#  '万_草书_王羲之_131072.gif',
#  '万_草书_王羲之_131073.gif',
#  '万_草书_王铎_131070.gif',
#  '万_草书_米芾_131065.gif',
#  '万_草书_索靖_131068.gif',
#  '万_草书_解缙_131062.gif',
#  '万_草书_詹景凤_131080.gif',
#  '万_草书_赵子昂_131085.gif',
#  '万_草书_赵子昂_131086.gif',
#  '万_草书_赵构_131083.gif',
#  '万_草书_赵雍_131084.gif',
#  '万_草书_陈淳_131051.gif',
#  '万_草书_鲜于枢_131075.gif',
#  '万_草书_黄庭坚_131060.gif',
#  '万_草书_黄庭坚_131061.gif',
#  '万_草书_黄慎_131059.gif',
#  '万_行书_何绍基_10960.gif',
#  '万_行书_卜舜年_10956.gif',
#  '万_行书_张即之_10984.gif',
#  '万_行书_徐渭_10982.gif',
#  '万_行书_敬世江_10961.gif',
#  '万_行书_文征明_10980.gif',
#  '万_行书_李建中_10962.gif',
#  '万_行书_柳公权_10963.gif',
#  '万_行书_楼钥_10964.gif',
#  '万_行书_欧阳询_10971.gif',
#  '万_行书_王羲之_10976.gif',
#  '万_行书_王羲之_10977.gif',
#  '万_行书_王羲之_10978.gif',
#  '万_行书_王羲之_10979.gif',
#  '万_行书_祝枝山_10985.gif',
#  '万_行书_米芾_10966.gif',
#  '万_行书_米芾_10967.gif',
#  '万_行书_米芾_10968.gif',
#  '万_行书_米芾_10969.gif',
#  '万_行书_米芾_10970.gif',
#  '万_行书_苏轼_10975.gif',
#  '万_行书_范成大_10959.gif',
#  '万_行书_董其昌_10958.gif',
#  '万_行书_蒲宗孟_10972.gif',
#  '万_行书_蒲宗孟_10973.gif',
#  '万_行书_钱澧_10974.gif',
#  '万_行书_陆柬之_10965.gif',
#  '万_行书_陈继儒_10957.gif',
#  '万_行书_颜真卿_10983.gif',
#  '万_行书_鲜于枢_10981.gif',
#  '万_隶书_华山神庙碑_78384.gif',
#  '万_隶书_唐玄宗_78397.gif',
#  '万_隶书_居延简_78386.gif',
#  '万_隶书_张迁碑_78399.gif',
#  '万_隶书_徐三庚_78398.gif',
#  '万_隶书_曹全碑_78382.gif',
#  '万_隶书_曹真碑_78383.gif',
#  '万_隶书_朱岷_78400.gif',
#  '万_隶书_楼兰简_78387.gif',
#  '万_隶书_泰山金刚经_78396.gif',
#  '万_隶书_马王堆帛书_78388.gif',
#  '万_隶书_马王堆帛书_78389.gif',
#  '万_隶书_马王堆帛书_78390.gif',
#  '万_隶书_马王堆帛书_78391.gif',
#  '万_隶书_马王堆帛书_78392.gif',
#  '万_隶书_马王堆帛书_78393.gif',
#  '万_隶书_马王堆帛书_78394.gif',
#  '万_隶书_马王堆简书_78395.gif',
#  '万_隶书_黄易_78385.gif',
#  '丈_楷书_柳公权_103120.gif',
#  '丈_楷书_柳公权_103121.gif',
#  '丈_楷书_虞世南_103124.gif',
#  '丈_楷书_虞世南_103125.gif',
#  '丈_楷书_颜真卿_103122.gif',
#  '丈_楷书_颜真卿_103123.gif',
#  '丈_篆书_吴昌硕_12.gif',
#  '丈_篆书_吴让之_13.gif',
#  '丈_篆书_赵之谦_14.gif',
#  '丈_草书_古法帖_131091.gif',
#  '丈_草书_徐伯清_131097.gif',
#  '丈_草书_敬世江_131093.gif',
#  '丈_草书_毛泽东_131096.gif',
#  '丈_草书_皇象_131092.gif',
#  '丈_草书_空海_131094.gif',
#  '丈_草书_赵子昂_131098.gif',
#  '丈_草书_陆应阳_131095.gif',
#  '丈_草书_陈献章_131090.gif',
#  '丈_行书_张凤翼_10991.gif',
#  '丈_行书_敬世江_10986.gif',
#  '丈_行书_王铎_10989.gif',
#  '丈_行书_米芾_10987.gif',
#  '丈_行书_米芾_10988.gif',
#  '丈_行书_赵孟頫_10992.gif',
#  '丈_行书_赵雍_10993.gif',
#  '丈_行书_鲜于枢_10990.gif',
#  '丈_隶书_邓石如_78401.gif',
#  '三_楷书_始平公造像_103135.gif',
#  '三_楷书_张猛龙碑_103140.gif',
#  '三_楷书_敬使君碑_103129.gif',
#  '三_楷书_杨大眼造像_103138.gif',
#  '三_楷书_柳公权_103130.gif',
#  '三_楷书_柳公权_103131.gif',
#  '三_楷书_欧阳询_103132.gif',
#  '三_楷书_欧阳询_103133.gif',
#  '三_楷书_石婉墓志_103134.gif',
#  '三_楷书_虞世南_103139.gif',
#  '三_楷书_褚遂良_103126.gif',
#  '三_楷书_褚遂良_103127.gif',
#  '三_楷书_褚遂良_103128.gif',
#  '三_楷书_颜真卿_103136.gif',
#  '三_楷书_颜真卿_103137.gif',
#  '三_篆书_吴昌硕_16.gif',
#  '三_篆书_杨沂孙_17.gif',
#  '三_篆书_说文解字_15.gif',
#  '三_草书_吴镇_131120.gif',
#  '三_草书_孙过庭_131110.gif',
#  '三_草书_宋克_131109.gif',
#  '三_草书_张瑞图_131123.gif',
#  '三_草书_徐伯清_131121.gif',
#  '三_草书_怀素_131102.gif',
#  '三_草书_怀素_131103.gif',
#  '三_草书_敬世江_131106.gif',
#  '三_草书_文天祥_131119.gif',
#  '三_草书_毛泽东_131108.gif',
#  '三_草书_王守仁_131111.gif',
#  '三_草书_王献之_131117.gif',
#  '三_草书_王献之_131118.gif',
#  '三_草书_王羲之_131112.gif',
#  '三_草书_王羲之_131113.gif',
#  '三_草书_王羲之_131114.gif',
#  '三_草书_王羲之_131115.gif',
#  '三_草书_王羲之_131116.gif',
#  '三_草书_皇象_131104.gif',
#  '三_草书_蔡襄_131099.gif',
#  '三_草书_虞世南_131122.gif',
#  '三_草书_贺知章_131101.gif',
#  '三_草书_赵构_131124.gif',
#  '三_草书_郑板桥_131125.gif',
#  '三_草书_陆居仁_131107.gif',
#  '三_草书_陈献章_131100.gif',
#  '三_草书_黄慎_131105.gif',
#  '三_行书_何绍基_10995.gif',
#  '三_行书_敬世江_10999.gif',
#  '三_行书_王献之_11004.gif',
#  '三_行书_王珣_11005.gif',
#  '三_行书_王羲之_11002.gif',
#  '三_行书_王羲之_11003.gif',
#  '三_行书_皇象_10996.gif',
#  '三_行书_苏轼_11001.gif',
#  '三_行书_蔡襄_10994.gif',
#  '三_行书_虞世南_11006.gif',
#  '三_行书_赵孟頫_11007.gif',
#  '三_行书_陆柬之_11000.gif',
#  '三_行书_黄庭坚_10998.gif',
#  '三_行书_黄道周_10997.gif',
#  '三_隶书_华山神庙碑_78405.gif',
#  '三_隶书_唐玄宗_78410.gif',
#  '三_隶书_居延简_78406.gif',
#  '三_隶书_曹全碑_78402.gif',
#  '三_隶书_礼器碑_78407.gif',
#  '三_隶书_衡方碑_78404.gif',
#  '三_隶书_赵之谦_78411.gif',
#  '三_隶书_顾蔼吉_78403.gif',
#  '三_隶书_马王堆帛书_78408.gif',
#  '三_隶书_马王堆帛书_78409.gif',
#  '上_楷书_太妃侯造像_103150.gif',
#  '上_楷书_敬使君碑_103145.gif',
#  '上_楷书_柳公权_103146.gif',
#  '上_楷书_柳公权_103147.gif',
#  '上_楷书_欧阳询_103149.gif',
#  '上_楷书_欧阳通_103148.gif',
#  '上_楷书_褚遂良_103141.gif',
#  '上_楷书_褚遂良_103142.gif',
#  '上_楷书_褚遂良_103143.gif',
#  '上_楷书_道匠造像_103144.gif',
#  '上_楷书_颜真卿_103151.gif',
#  '上_篆书_吴大澄_22.gif',
#  '上_篆书_吴昌硕_20.gif',
#  '上_篆书_吴昌硕_21.gif',
#  '上_篆书_曾纪泽_23.gif',
#  '上_篆书_莫友芝_19.gif',
#  '上_篆书_邓石如_18.gif',
#  '上_草书_康里子山_131133.gif',
#  '上_草书_康里子山_131134.gif',
#  '上_草书_张旭_131151.gif',
#  '上_草书_张旭_131152.gif',
#  '上_草书_徐伯清_131144.gif',
#  '上_草书_徐伯清_131145.gif',
#  '上_草书_徐伯清_131146.gif',
#  '上_草书_徐伯清_131147.gif',
#  '上_草书_徐伯清_131148.gif',
#  '上_草书_徐伯清_131149.gif',
#  '上_草书_怀素_131128.gif',
#  '上_草书_敬世江_131132.gif',
#  '上_草书_智永_131154.gif',
#  '上_草书_智永_131155.gif',
#  '上_草书_智永_131156.gif',
#  '上_草书_李世民_131135.gif',
#  '上_草书_杨凝式_131150.gif',
#  '上_草书_毛泽东_131136.gif',
#  '上_草书_王宠_131139.gif',
#  '上_草书_王献之_131142.gif',
#  '上_草书_王羲之_131141.gif',
#  '上_草书_王铎_131140.gif',
#  '上_草书_皇象_131129.gif',
#  '上_草书_祝枝山_131157.gif',
#  '上_草书_米芾_131137.gif',
#  '上_草书_米芾_131138.gif',
#  '上_草书_蔡襄_131126.gif',
#  '上_草书_赵子昂_131153.gif',
#  '上_草书_陈淳_131127.gif',
#  '上_草书_鲜于枢_131143.gif',
#  '上_草书_黄庭坚_131130.gif',
#  '上_草书_黄庭坚_131131.gif',
#  '上_行书_司马睿_11018.gif',
#  '上_行书_张旭_11032.gif',
#  '上_行书_张瑞图_11030.gif',
#  '上_行书_张瑞图_11031.gif',
#  '上_行书_怀素_11011.gif',
#  '上_行书_敬世江_11014.gif',
#  '上_行书_智永_11036.gif',
#  '上_行书_欧阳询_11017.gif',
#  '上_行书_王献之_11026.gif',
#  '上_行书_王献之_11027.gif',
#  '上_行书_王献之_11028.gif',
#  '上_行书_王羲之_11022.gif',
#  '上_行书_王羲之_11023.gif',
#  '上_行书_王羲之_11024.gif',
#  '上_行书_王羲之_11025.gif',
#  '上_行书_王铎_11021.gif',
#  '上_行书_祝世禄_11037.gif',
#  '上_行书_祝枝山_11038.gif',
#  '上_行书_米芾_11015.gif',
#  '上_行书_米芾_11016.gif',
#  '上_行书_苏轼_11019.gif',
#  '上_行书_董其昌_11010.gif',
#  '上_行书_蔡襄_11008.gif',
#  '上_行书_褚遂良_11009.gif',
#  '上_行书_赵之谦_11035.gif',
#  '上_行书_赵孟坚_11033.gif',
#  '上_行书_赵孟頫_11034.gif',
#  '上_行书_隋人_11020.gif',
#  '上_行书_鲜于枢_11029.gif',
#  '上_行书_黄庭坚_11012.gif',
#  '上_行书_黄庭坚_11013.gif',
#  '上_隶书_史晨碑_78421.gif',
#  '上_隶书_吴让之_78423.gif',
#  '上_隶书_唐玄宗_78422.gif',
#  '上_隶书_孔彪碑_78417.gif',
#  '上_隶书_居延简_78416.gif',
#  '上_隶书_张迁碑_78425.gif',
#  '上_隶书_曹全碑_78413.gif',
#  '上_隶书_曹全碑_78414.gif',
#  '上_隶书_武威简_78424.gif',
#  '上_隶书_白石君碑_78412.gif',
#  '上_隶书_韩仁铭_78415.gif',
#  '上_隶书_马王堆帛书_78418.gif',
#  '上_隶书_马王堆帛书_78419.gif',
#  '上_隶书_马王堆帛书_78420.gif',
#  '下_楷书_文征明_103158.gif',
#  '下_楷书_柳公权_103154.gif',
#  '下_楷书_柳公权_103155.gif',
#  '下_楷书_欧阳询_103156.gif',
#  '下_楷书_欧阳询_103157.gif',
#  '下_楷书_褚遂良_103152.gif',
#  '下_楷书_褚遂良_103153.gif',
#  '下_楷书_颜真卿_103159.gif',
#  '下_楷书_颜真卿_103160.gif',
#  '下_篆书_会稽刻石_24.gif',
#  '下_篆书_吴昌硕_27.gif',
#  '下_篆书_徐三庚_28.gif',
#  '下_篆书_曾纪泽_30.gif',
#  '下_篆书_杨沂孙_29.gif',
#  '下_篆书_罗振玉_25.gif',
#  '下_篆书_钱玷_26.gif',
#  '下_草书_司马炎_131172.gif',
#  '下_草书_孙过庭_131173.gif',
#  '下_草书_孙过庭_131174.gif',
#  '下_草书_张旭_131203.gif',
#  '下_草书_张瑞图_131202.gif',
#  '下_草书_徐伯清_131195.gif',
#  '下_草书_徐伯清_131196.gif',
#  '下_草书_徐伯清_131197.gif',
#  '下_草书_徐伯清_131198.gif',
#  '下_草书_徐伯清_131199.gif',
#  '下_草书_徐伯清_131200.gif',
#  '下_草书_怀素_131162.gif',
#  '下_草书_怀素_131163.gif',
#  '下_草书_敬世江_131166.gif',
#  '下_草书_文征明_131193.gif',
#  '下_草书_智永_131206.gif',
#  '下_草书_月仪帖_131201.gif',
#  '下_草书_毛泽东_131168.gif',
#  '下_草书_沈粲_131170.gif',
#  '下_草书_沈粲_131171.gif',
#  '下_草书_王宠_131175.gif',
#  '下_草书_王导_131178.gif',
#  '下_草书_王慈_131176.gif',
#  '下_草书_王慈_131177.gif',
#  '下_草书_王献之_131190.gif',
#  '下_草书_王献之_131191.gif',
#  '下_草书_王羲之_131181.gif',
#  '下_草书_王羲之_131182.gif',
#  '下_草书_王羲之_131183.gif',
#  '下_草书_王羲之_131184.gif',
#  '下_草书_王羲之_131185.gif',
#  '下_草书_王羲之_131186.gif',
#  '下_草书_王羲之_131187.gif',
#  '下_草书_王羲之_131188.gif',
#  '下_草书_王羲之_131189.gif',
#  '下_草书_王蒙_131180.gif',
#  '下_草书_王衍_131192.gif',
#  '下_草书_王铎_131179.gif',
#  '下_草书_祝枝山_131207.gif',
#  '下_草书_米芾_131169.gif',
#  '下_草书_蔡襄_131158.gif',
#  '下_草书_赵佶_131205.gif',
#  '下_草书_赵构_131204.gif',
#  '下_草书_陆游_131167.gif',
#  '下_草书_陈淳_131159.gif',
#  '下_草书_韩道亨_131161.gif',
#  '下_草书_顾可久_131160.gif',
#  '下_草书_鲜于枢_131194.gif',
#  '下_草书_黄庭坚_131164.gif',
#  '下_草书_黄庭坚_131165.gif',
#  '下_行书_宋儋_11048.gif',
#  '下_行书_张瑞图_11055.gif',
#  '下_行书_敬世江_11042.gif',
#  '下_行书_李邕_11043.gif',
#  '下_行书_杜牧_11040.gif',
#  '下_行书_欧阳询_11046.gif',
#  '下_行书_沈周_11047.gif',
#  '下_行书_王献之_11051.gif',
#  '下_行书_王献之_11052.gif',
#  '下_行书_王羲之_11049.gif',
#  '下_行书_王羲之_11050.gif',
#  '下_行书_米芾_11044.gif',
#  '下_行书_米芾_11045.gif',
#  '下_行书_萧思话_11053.gif',
#  '下_行书_蔡襄_11039.gif',
#  '下_行书_赵孟頫_11056.gif',
#  '下_行书_颜真卿_11054.gif',
#  '下_行书_黄庭坚_11041.gif',
#  '下_隶书_伊秉绶_78435.gif',
#  '下_隶书_唐玄宗_78433.gif',
#  '下_隶书_居延简_78427.gif',
#  '下_隶书_张表碑_78436.gif',
#  '下_隶书_校官碑_78434.gif',
#  '下_隶书_莫友芝_78432.gif',
#  '下_隶书_衡方碑_78426.gif',
#  '下_隶书_马王堆帛书_78428.gif',
#  '下_隶书_马王堆帛书_78429.gif',
#  '下_隶书_马王堆帛书_78430.gif',
#  '下_隶书_马王堆帛书_78431.gif',
#  '不_楷书_一弗造像_103174.gif',
#  '不_楷书_中岳灵庙碑_103178.gif',
#  '不_楷书_张元祖造像_103177.gif',
#  '不_楷书_张旭_103176.gif',
#  '不_楷书_张猛龙碑_103175.gif',
#  '不_楷书_李邕_103164.gif',
#  '不_楷书_柳公权_103165.gif',
#  '不_楷书_柳公权_103166.gif',
#  '不_楷书_欧阳询_103167.gif',
#  '不_楷书_王庭筠_103170.gif',
#  '不_楷书_王知敬_103171.gif',
#  '不_楷书_石婉墓志_103168.gif',
#  '不_楷书_苏轼_103169.gif',
#  '不_楷书_褚遂良_103161.gif',
#  '不_楷书_褚遂良_103162.gif',
#  '不_楷书_贾使君碑_103163.gif',
#  '不_楷书_钟繇_103179.gif',
#  '不_楷书_钟繇_103180.gif',
#  '不_楷书_颜真卿_103172.gif',
#  '不_楷书_颜真卿_103173.gif',
#  '不_篆书_会稽刻石_33.gif',
#  '不_篆书_吴大澄_36.gif',
#  '不_篆书_吴昌硕_35.gif',
#  '不_篆书_杨沂孙_37.gif',
#  '不_篆书_盂鼎_38.gif',
#  '不_篆书_胡澍_32.gif',
#  '不_篆书_说文解字_34.gif',
#  '不_篆书_赵之谦_39.gif',
#  '不_篆书_邓石如_31.gif',
#  '不_草书_何绍基_131215.gif',
#  '不_草书_吴镇_131260.gif',
#  '不_草书_吴镇_131261.gif',
#  '不_草书_宋儋_131230.gif',
#  '不_草书_宋克_131231.gif',
#  '不_草书_康里子山_131224.gif',
#  '不_草书_康里子山_131225.gif',
#  '不_草书_张华_131285.gif',
#  '不_草书_张瑞图_131286.gif',
#  '不_草书_归庄_131214.gif',
#  '不_草书_徐伯清_131264.gif',
#  '不_草书_徐伯清_131265.gif',
#  '不_草书_徐伯清_131266.gif',
#  '不_草书_徐伯清_131267.gif',
#  '不_草书_徐伯清_131268.gif',
#  '不_草书_徐伯清_131269.gif',
#  '不_草书_徐伯清_131270.gif',
#  '不_草书_徐伯清_131271.gif',
#  '不_草书_徐伯清_131272.gif',
#  '不_草书_徐伯清_131273.gif',
#  '不_草书_徐伯清_131274.gif',
#  '不_草书_徐伯清_131275.gif',
#  '不_草书_徐伯清_131276.gif',
#  '不_草书_徐伯清_131277.gif',
#  '不_草书_徐伯清_131278.gif',
#  '不_草书_徐伯清_131279.gif',
#  '不_草书_徐渭_131280.gif',
#  '不_草书_怀素_131217.gif',
#  '不_草书_怀素_131218.gif',
#  '不_草书_怀素_131219.gif',
#  '不_草书_敬世江_131223.gif',
#  '不_草书_智永_131289.gif',
#  '不_草书_李世民_131226.gif',
#  '不_草书_毛泽东_131227.gif',
#  '不_草书_沈粲_131229.gif',
#  '不_草书_王守仁_131238.gif',
#  '不_草书_王导_131233.gif',
#  '不_草书_王导_131234.gif',
#  '不_草书_王志_131259.gif',
#  '不_草书_王慈_131232.gif',
#  '不_草书_王敦_131235.gif',
#  '不_草书_王献之_131255.gif',
#  '不_草书_王献之_131256.gif',
#  '不_草书_王献之_131257.gif',
#  '不_草书_王献之_131258.gif',
#  '不_草书_王羲之_131239.gif',
#  '不_草书_王羲之_131240.gif',
#  '不_草书_王羲之_131241.gif',
#  '不_草书_王羲之_131242.gif',
#  '不_草书_王羲之_131243.gif',
#  '不_草书_王羲之_131244.gif',
#  '不_草书_王羲之_131245.gif',
#  '不_草书_王羲之_131246.gif',
#  '不_草书_王羲之_131247.gif',
#  '不_草书_王羲之_131248.gif',
#  '不_草书_王羲之_131249.gif',
#  '不_草书_王羲之_131250.gif',
#  '不_草书_王羲之_131251.gif',
#  '不_草书_王羲之_131252.gif',
#  '不_草书_王羲之_131253.gif',
#  '不_草书_王羲之_131254.gif',
#  '不_草书_王铎_131236.gif',
#  '不_草书_王铎_131237.gif',
#  '不_草书_祝枝山_131290.gif',
#  '不_草书_祝枝山_131291.gif',
#  '不_草书_祝枝山_131292.gif',
#  '不_草书_祝枝山_131293.gif',
#  '不_草书_米芾_131228.gif',
#  '不_草书_羊欣_131284.gif',
#  '不_草书_蔡襄_131208.gif',
#  '不_草书_薛绍彭_131281.gif',
#  '不_草书_薛绍彭_131282.gif',
#  '不_草书_褚遂良_131213.gif',
#  '不_草书_贺知章_131216.gif',
#  '不_草书_赵构_131287.gif',
#  '不_草书_赵构_131288.gif',
#  '不_草书_陈伯智_131209.gif',
#  '不_草书_陈淳_131210.gif',
#  '不_草书_陈绎曾_131211.gif',
#  '不_草书_陈绎曾_131212.gif',
#  '不_草书_颜真卿_131283.gif',
#  '不_草书_鲜于枢_131262.gif',
#  '不_草书_鲜于枢_131263.gif',
#  '不_草书_黄庭坚_131221.gif',
#  '不_草书_黄庭坚_131222.gif',
#  '不_草书_黄慎_131220.gif',
#  '不_行书_吴琚_11102.gif',
#  '不_行书_宋曹_11077.gif',
#  '不_行书_张从申_11108.gif',
#  '不_行书_张照_11110.gif',
#  '不_行书_张翼_11109.gif',
#  '不_行书_张芝_11111.gif',
#  '不_行书_徐渭_11103.gif',
#  '不_行书_怀素_11061.gif',
#  '不_行书_敬世江_11065.gif',
#  '不_行书_明人_11075.gif',
#  '不_行书_李世民_11066.gif',
#  '不_行书_李世民_11067.gif',
#  '不_行书_柳公权_11068.gif',
#  '不_行书_柳公权_11069.gif',
#  '不_行书_汇辑_11063.gif',
#  '不_行书_王宠_11078.gif',
#  '不_行书_王导_11080.gif',
#  '不_行书_王慈_11079.gif',
#  '不_行书_王文治_11082.gif',
#  '不_行书_王民_11081.gif',
#  '不_行书_王献之_11096.gif',
#  '不_行书_王献之_11097.gif',
#  '不_行书_王献之_11098.gif',
#  '不_行书_王献之_11099.gif',
#  '不_行书_王献之_11100.gif',
#  '不_行书_王献之_11101.gif',
#  '不_行书_王羲之_11083.gif',
#  '不_行书_王羲之_11084.gif',
#  '不_行书_王羲之_11085.gif',
#  '不_行书_王羲之_11086.gif',
#  '不_行书_王羲之_11087.gif',
#  '不_行书_王羲之_11088.gif',
#  '不_行书_王羲之_11089.gif',
#  '不_行书_王羲之_11090.gif',
#  '不_行书_王羲之_11091.gif',
#  '不_行书_王羲之_11092.gif',
#  '不_行书_王羲之_11093.gif',
#  '不_行书_王羲之_11094.gif',
#  '不_行书_王羲之_11095.gif',
#  '不_行书_米芾_11071.gif',
#  '不_行书_米芾_11072.gif',
#  '不_行书_米芾_11073.gif',
#  '不_行书_米芾_11074.gif',
#  '不_行书_董其昌_11058.gif',
#  '不_行书_董其昌_11059.gif',
#  '不_行书_薛绍彭_11104.gif',
#  '不_行书_虞世南_11107.gif',
#  '不_行书_赵孟頫_11112.gif',
#  '不_行书_近人_11064.gif',
#  '不_行书_邵二泉_11076.gif',
#  '不_行书_陆柬之_11070.gif',
#  '不_行书_陈伯智_11057.gif',
#  '不_行书_颜真卿_11105.gif',
#  '不_行书_颜真卿_11106.gif',
#  '不_行书_高正臣_11060.gif',
#  '不_行书_黄庭坚_11062.gif',
#  '不_隶书_华山神庙碑_78440.gif',
#  '不_隶书_史晨碑_78453.gif',
#  '不_隶书_叶慧明碑_78457.gif',
#  '不_隶书_唐玄宗_78454.gif',
#  '不_隶书_景君碑_78442.gif',
#  '不_隶书_曹全碑_78437.gif',
#  '不_隶书_杨统碑_78456.gif',
#  '不_隶书_王基碑_78455.gif',
#  '不_隶书_礼器碑_78443.gif',
#  '不_隶书_礼器碑_78444.gif',
#  '不_隶书_简牍_78441.gif',
#  '不_隶书_衡方碑_78439.gif',
#  '不_隶书_郭有道碑_78438.gif',
#  '不_隶书_马王堆帛书_78445.gif',
#  '不_隶书_马王堆帛书_78446.gif',
#  '不_隶书_马王堆帛书_78447.gif',
#  '不_隶书_马王堆帛书_78448.gif',
#  '不_隶书_马王堆帛书_78449.gif',
#  '不_隶书_马王堆帛书_78450.gif',
#  '不_隶书_马王堆帛书_78451.gif',
#  '不_隶书_马王堆简书_78452.gif',
#  '与_楷书_张从申_103189.gif',
#  '与_楷书_智永_103190.gif',
#  '与_楷书_李璧碑_103183.gif',
#  '与_楷书_柳公权_103184.gif',
#  '与_楷书_欧阳询_103185.gif',
#  '与_楷书_蔡襄_103181.gif',
#  '与_楷书_虞世南_103188.gif',
#  '与_楷书_褚遂良_103182.gif',
#  '与_楷书_钟繇_103191.gif',
#  '与_楷书_颜真卿_103187.gif',
#  '与_楷书_魏栖梧_103186.gif',
#  '与_篆书_吴昌硕_43.gif',
#  '与_篆书_说文解字_41.gif',
#  '与_篆书_说文解字_42.gif',
#  '与_篆书_邓石如_40.gif',
#  '与_草书_吴镇_131304.gif',
#  '与_草书_徐伯清_131306.gif',
#  '与_草书_徐伯清_131307.gif',
#  '与_草书_徐伯清_131308.gif',
#  '与_草书_徐伯清_131309.gif',
#  '与_草书_徐伯清_131310.gif',
#  '与_草书_徐伯清_131311.gif',
#  '与_草书_徐伯清_131312.gif',
#  '与_草书_徐伯清_131313.gif',
#  '与_草书_徐伯清_131314.gif',
#  '与_草书_徐伯清_131315.gif',
#  '与_草书_怀素_131295.gif',
#  '与_草书_敬世江_131296.gif',
#  '与_草书_智永_131317.gif',
#  '与_草书_李世民_131297.gif',
#  '与_草书_毛泽东_131298.gif',
#  '与_草书_王献之_131303.gif',
#  '与_草书_王羲之_131300.gif',
#  '与_草书_王羲之_131301.gif',
#  '与_草书_王羲之_131302.gif',
#  '与_草书_王铎_131299.gif',
#  '与_草书_祝枝山_131318.gif',
#  '与_草书_褚遂良_131294.gif',
#  '与_草书_赵子昂_131316.gif',
#  '与_草书_鲜于枢_131305.gif',
#  '与_行书_唐寅_11124.gif',
#  '与_行书_张弼_11131.gif',
#  '与_行书_敬世江_11115.gif',
#  '与_行书_李世民_11116.gif',
#  '与_行书_林逋_11117.gif',
#  '与_行书_柳公权_11118.gif',
#  '与_行书_欧阳询_11121.gif',
#  '与_行书_王宠_11125.gif',
#  '与_行书_王献之_11129.gif',
#  '与_行书_王羲之_11128.gif',
#  '与_行书_王铎_11126.gif',
#  '与_行书_王铎_11127.gif',
#  '与_行书_米芾_11120.gif',
#  '与_行书_苏轼_11122.gif',
#  '与_行书_苏轼_11123.gif',
#  '与_行书_董其昌_11113.gif',
#  '与_行书_赵孟頫_11132.gif',
#  '与_行书_赵孟頫_11133.gif',
#  '与_行书_赵孟頫_11134.gif',
#  '与_行书_赵孟頫_11135.gif',
#  '与_行书_郑审则_11136.gif',
#  '与_行书_陆柬之_11119.gif',
#  '与_行书_颜真卿_11130.gif',
#  '与_行书_黄庭坚_11114.gif',
#  '与_隶书_丁敬_78460.gif',
#  '与_隶书_唐玄宗_78464.gif',
#  '与_隶书_曹全碑_78458.gif',
#  '与_隶书_赵之谦_78465.gif',
#  '与_隶书_陈鸿寿_78459.gif',
#  '与_隶书_马王堆帛书_78461.gif',
#  '与_隶书_马王堆帛书_78462.gif',
#  '与_隶书_马王堆帛书_78463.gif',
#  '丐_楷书_张浚_103193.gif',
#  '丐_楷书_颜真卿_103192.gif',
#  '丐_草书_徐伯清_131321.gif',
#  '丐_草书_敬世江_131320.gif',
#  '丐_草书_蔡襄_131319.gif',
#  '丐_行书_张浚_11141.gif',
#  '丐_行书_敬世江_11138.gif',
#  '丐_行书_王庭筠_11140.gif',
#  '丐_行书_王铎_11139.gif',
#  '丐_行书_蔡襄_11137.gif',
#  '丐_行书_赵孟頫_11142.gif',
#  '丑_楷书_孙秋生造像_103198.gif',
#  '丑_楷书_敬使君碑_103197.gif',
#  '丑_楷书_褚遂良_103194.gif',
#  '丑_楷书_褚遂良_103195.gif',
#  '丑_楷书_褚遂良_103196.gif',
#  '丑_楷书_赵之谦_103202.gif',
#  '丑_楷书_颜真卿_103199.gif',
#  '丑_楷书_颜真卿_103200.gif',
#  '丑_楷书_颜真卿_103201.gif',
#  '丑_篆书_吴大澂_46.gif',
#  '丑_篆书_王澍_45.gif',
#  '丑_篆书_罗振玉_44.gif',
#  '丑_草书_孙过庭_131324.gif',
#  '丑_草书_徐伯清_131327.gif',
#  '丑_草书_敬世江_131322.gif',
#  '丑_草书_毛泽东_131323.gif',
#  '丑_草书_王羲之_131326.gif',
#  '丑_草书_王铎_131325.gif',
#  '丑_行书_丰坊_11144.gif',
#  '丑_行书_何绍基_11145.gif',
#  '丑_行书_敬世江_11148.gif',
#  '丑_行书_李倜_11149.gif',
#  '丑_行书_李治_11150.gif',
#  '丑_行书_沈周_11152.gif',
#  '丑_行书_沈周_11153.gif',
#  '丑_行书_沈藻_11151.gif',
#  '丑_行书_王献之_11158.gif',
#  '丑_行书_王羲之_11156.gif',
#  '丑_行书_王羲之_11157.gif',
#  '丑_行书_王蒙_11155.gif',
#  '丑_行书_苏迟_11154.gif',
#  '丑_行书_董其昌_11143.gif',
#  '丑_行书_近人_11147.gif',
#  '丑_行书_鲜于枢_11159.gif',
#  '丑_行书_鲜于枢_11160.gif',
#  '丑_行书_黄庭坚_11146.gif',
#  '丑_隶书_孔彪碑_78469.gif',
#  '丑_隶书_居延简_78468.gif',
#  '丑_隶书_张表碑_78476.gif',
#  '丑_隶书_衡方碑_78467.gif',
#  '丑_隶书_谯君碑_78475.gif',
#  '丑_隶书_邓石如_78466.gif',
#  '丑_隶书_隶辨_78470.gif',
#  '丑_隶书_马王堆帛书_78471.gif',
#  '丑_隶书_马王堆帛书_78472.gif',
#  '丑_隶书_马王堆帛书_78473.gif',
#  '丑_隶书_马王堆帛书_78474.gif',
#  '专_楷书_敬使君碑_103204.gif',
#  '专_楷书_狄知孙残碑_103203.gif',
#  '专_楷书_虞世南_103208.gif',
#  '专_楷书_颜真卿_103205.gif',
#  '专_楷书_颜真卿_103206.gif',
#  '专_楷书_颜真卿_103207.gif',
#  '专_篆书_会稽刻石_47.gif',
#  '专_篆书_吴让之_48.gif',
#  '专_草书_孙过庭_131334.gif',
#  '专_草书_孙过庭_131335.gif',
#  '专_草书_康里子山_131331.gif',
#  '专_草书_敬世江_131330.gif',
#  '专_草书_李世民_131332.gif',
#  '专_草书_毛泽东_131333.gif',
#  '专_草书_蔡襄_131328.gif',
#  '专_草书_韩道亨_131329.gif',
#  '专_行书_敬世江_11161.gif',
#  '专_行书_李邕_11162.gif',
#  '专_行书_米芾_11163.gif',
#  '专_行书_赵雍_11164.gif',
#  '专_隶书_吴睿_78480.gif',
#  '专_隶书_李隆基_78477.gif',
#  '专_隶书_杨统碑_78481.gif',
#  '专_隶书_马王堆帛书_78478.gif',
#  '专_隶书_马王堆帛书_78479.gif',
#  '且_楷书_安乐王墓志_103209.gif',
#  '且_楷书_柳公权_103210.gif',
#  '且_楷书_柳公权_103211.gif',
#  '且_楷书_欧阳通_103212.gif',
#  '且_楷书_虞世南_103214.gif',
#  '且_楷书_赵佶_103215.gif',
#  '且_楷书_赵孟頫_103216.gif',
#  '且_楷书_颜真卿_103213.gif',
#  '且_篆书_吴昌硕_50.gif',
#  '且_篆书_罗振玉_49.gif',
#  '且_草书_张芝_131349.gif',
#  '且_草书_徐伯清_131346.gif',
#  '且_草书_徐伯清_131347.gif',
#  '且_草书_徐伯清_131348.gif',
#  '且_草书_怀素_131336.gif',
#  '且_草书_敬世江_131340.gif',
#  '且_草书_欧阳询_131343.gif',
#  '且_草书_毛泽东_131342.gif',
#  '且_草书_王献之_131345.gif',
#  '且_草书_王羲之_131344.gif',
#  '且_草书_祝枝山_131352.gif',
#  '且_草书_蒋善进_131339.gif',
#  '且_草书_赵佶_131350.gif',
#  '且_草书_赵子昂_131351.gif',
#  '且_草书_陆居仁_131341.gif',
#  '且_草书_黄庭坚_131337.gif',
#  '且_草书_黄庭坚_131338.gif',
#  '且_行书_何绍基_11165.gif',
#  '且_行书_唐寅_11175.gif',
#  '且_行书_张即之_11179.gif',
#  '且_行书_揭傒斯_11166.gif',
#  '且_行书_揭傒斯_11167.gif',
#  '且_行书_敬世江_11168.gif',
#  '且_行书_文征明_11178.gif',
#  '且_行书_智永_11181.gif',
#  '且_行书_李世民_11169.gif',
#  '且_行书_李邕_11170.gif',
#  '且_行书_李邕_11171.gif',
#  '且_行书_李邕_11172.gif',
#  '且_行书_王羲之_11177.gif',
#  '且_行书_王铎_11176.gif',
#  '且_行书_米芾_11173.gif',
#  '且_行书_米芾_11174.gif',
#  '且_行书_郑板桥_11180.gif',
#  '且_隶书_张迁碑_78487.gif',
#  '且_隶书_曹全碑_78482.gif',
#  '且_隶书_曹全碑_78483.gif',
#  '且_隶书_李隆基_78485.gif',
#  '且_隶书_杨守敬_78486.gif',
#  '且_隶书_衡方碑_78484.gif',
#  '丕_楷书_哀帝_103217.gif',
#  '丕_楷书_欧阳询_103218.gif',
#  '丕_楷书_苏轼_103219.gif',
#  '丕_楷书_虞世南_103220.gif',
#  '丕_篆书_说文解字_52.gif',
#  '丕_篆书_邓石如_51.gif',
#  '丕_草书_徐伯清_131357.gif',
#  '丕_草书_怀素_131354.gif',
#  '丕_草书_敬世江_131355.gif',
#  '丕_草书_毛泽东_131356.gif',
#  '丕_草书_草书韵会_131353.gif',
#  '丕_行书_字汇_11185.gif',
#  '丕_行书_敬世江_11183.gif',
#  '丕_行书_李治_11184.gif',
#  '丕_行书_高正臣_11182.gif',
#  '丕_隶书_吴让之_78490.gif',
#  '丕_隶书_唐玄宗_78489.gif',
#  '丕_隶书_隶辨_78488.gif',
#  '世_楷书_安定王墓志_103221.gif',
#  '世_楷书_智永_103234.gif',
#  '世_楷书_李璧碑_103227.gif',
#  '世_楷书_柳公权_103228.gif',
#  '世_楷书_柳公权_103229.gif',
#  '世_楷书_牛橛造像_103230.gif',
#  '世_楷书_虞世南_103233.gif',
#  '世_楷书_褚遂良_103222.gif',
#  '世_楷书_褚遂良_103223.gif',
#  '世_楷书_褚遂良_103224.gif',
#  '世_楷书_褚遂良_103225.gif',
#  '世_楷书_颜真卿_103232.gif',
#  '世_楷书_高贞碑_103226.gif',
#  '世_楷书_魏灵藏造像_103231.gif',
#  '世_篆书_吴大澄_53.gif',
#  '世_篆书_吴让之_54.gif',
#  '世_篆书_杨沂孙_55.gif',
#  '世_草书_吴镇_131371.gif',
#  '世_草书_孙过庭_131368.gif',
#  '世_草书_张旭_131380.gif',
#  '世_草书_张瑞图_131379.gif',
#  '世_草书_徐伯清_131374.gif',
#  '世_草书_徐伯清_131375.gif',
#  '世_草书_徐伯清_131376.gif',
#  '世_草书_徐伯清_131377.gif',
#  '世_草书_敬世江_131362.gif',
#  '世_草书_智永_131383.gif',
#  '世_草书_李怀琳_131363.gif',
#  '世_草书_李怀琳_131364.gif',
#  ...]
